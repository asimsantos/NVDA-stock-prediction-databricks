-- %%
USE CATALOG main;
USE SCHEMA stocks;

SELECT
  date,
  actual_close,
  predicted_close_lstm
FROM nvda_predictions_lstm_nextday
ORDER BY date;
-- Out:
-- Databricks visualization. Run in Databricks to view.
