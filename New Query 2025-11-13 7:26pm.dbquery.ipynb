-- %%
USE CATALOG main;
USE SCHEMA stocks;

SELECT
  date,
  actual_fwd_30d_return,
  pred_fwd_30d_return_lstm
FROM nvda_predictions_lstm_30d_return
ORDER BY date;
-- Out:
-- Databricks visualization. Run in Databricks to view.
